# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramkirks/My_Python-Code/blob/main/Practice_10_12_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def array_swap(list_):
  return(sorted(list_, reverse=True))

# %%
list_=['G','B','R','R','B','R','G']
array_swap(list_)
# Out:
# ['R', 'R', 'R', 'G', 'G', 'B', 'B']
