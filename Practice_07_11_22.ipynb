# %% [markdown]
# <a href="https://colab.research.google.com/github/Ramkirks/My_Python-Code/blob/main/Practice_07_11_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def find_correct_combination(list_,k):
  num =k
  m=0
  for j in range(len(list_)):
    for i in list_:
      if num == i+ list_[m]:
        return (i, list_[m])
    else:
      pass
    m+=1
  return f'There is no matching number found'

list_ =[11,13,15,3,8,5,6,12,10,15,7,9,6,5]
find_correct_combination(list_,17)
# Out:
# (6, 11)
